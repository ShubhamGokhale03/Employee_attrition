# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns
import plotly.offline as py 
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data=pd.read_csv('part-00000-89e4e981-b690-48ea-9e84-dbd29c002ff9-c000.csv',header=None)

# %%
header=['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
data. columns=header

# %%
data.tail()
# Out:
#         Age Attrition BusinessTravel  DailyRate       Department  \
# 701288   55        No  Travel_Rarely        653  Human Resources
# 701289   22       Yes  Travel_Rarely       1401         Software
# 701290   48       Yes  Travel_Rarely        292    Life Sciences
# 701291   53        No  Travel_Rarely       1440  Human Resources
# 701292   29       Yes  Travel_Rarely        583            Sales
#
#         DistanceFromHome  Education    EducationField  \
# 701288                 1          2         Marketing
# 701289                22          4   Human Resources
# 701290                39          3         Marketing
# 701291                24          2     Life Sciences
# 701292                35          2  Technical Degree
#
#         EnvironmentSatisfaction  Gender  ...  PercentSalaryHike  \
# 701288                        1    Male  ...                 15
# 701289                        2  Female  ...                 16
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701293 entries, 0 to 701292
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       701293 non-null  int64
#  1   Attrition                 701293 non-null  object
#  2   BusinessTravel            701293 non-null  object
#  3   DailyRate                 701293 non-null  int64
#  4   Department                701293 non-null  object
#  5   DistanceFromHome          701293 non-null  int64
#  6   Education                 701293 non-null  int64
#  7   EducationField            701293 non-null  object
#  8   EmployeeCount             701293 non-null  int64
#  9   EmployeeNumber            701293 non-null  int64
#  10  EnvironmentSatisfaction   701293 non-null  int64
#  11  Gender                    701293 non-null  object
#  12  HourlyRate                701293 non-null  int64
# ...

# %%
data.plot (kind='box',subplots=True,layout=(13,2),figsize=(20,30))
# Out:
# Age                            AxesSubplot(0.125,0.83;0.352273x0.05)
# DailyRate                   AxesSubplot(0.547727,0.83;0.352273x0.05)
# DistanceFromHome               AxesSubplot(0.125,0.77;0.352273x0.05)
# Education                   AxesSubplot(0.547727,0.77;0.352273x0.05)
# EmployeeCount                  AxesSubplot(0.125,0.71;0.352273x0.05)
# EmployeeNumber              AxesSubplot(0.547727,0.71;0.352273x0.05)
# EnvironmentSatisfaction        AxesSubplot(0.125,0.65;0.352273x0.05)
# HourlyRate                  AxesSubplot(0.547727,0.65;0.352273x0.05)
# JobInvolvement                 AxesSubplot(0.125,0.59;0.352273x0.05)
# JobLevel                    AxesSubplot(0.547727,0.59;0.352273x0.05)
# JobSatisfaction                AxesSubplot(0.125,0.53;0.352273x0.05)
# MonthlyIncome               AxesSubplot(0.547727,0.53;0.352273x0.05)
# MonthlyRate                    AxesSubplot(0.125,0.47;0.352273x0.05)
# NumCompaniesWorked          AxesSubplot(0.547727,0.47;0.352273x0.05)
# ...

# %%
data.shape
# Out:
# (701293, 35)

# %% [markdown]
# # Remove unneccessary columns

# %%
data.drop(columns=['StandardHours','EmployeeCount','Over18','EmployeeNumber','StockOptionLevel'],inplace=True)

# %%
data.shape
# Out:
# (701293, 30)

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
data.describe()
# Out:
#                  Age      DailyRate  DistanceFromHome      Education  \
# count  701293.000000  701293.000000     701293.000000  701293.000000
# mean       39.462276     797.795794         26.085820       2.943695
# std        12.137907     476.530710         14.028878       1.450507
# min        18.000000      11.000000          1.000000       1.000000
# 25%        29.000000     445.000000         14.000000       2.000000
# 50%        39.000000     798.000000         28.000000       3.000000
# 75%        50.000000    1142.000000         38.000000       4.000000
# max        60.000000   13459.000000         50.000000       5.000000
#
#        EnvironmentSatisfaction     HourlyRate  JobInvolvement       JobLevel  \
# count            701293.000000  701293.000000   701293.000000  701293.000000
# mean                  2.291145     114.893741        1.837664       2.941594
# std                   1.129057      53.812843        1.043701       1.452344
# ...

# %%
Attrition_count = data['Attrition'].value_counts()
Attrition_count
# Out:
# No     402917
# Yes    298376
# Name: Attrition, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 4

# %%
data=data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (701289, 30)

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(data.corr(),annot=True, cmap='Blues',annot_kws={"size":14})
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11940\1825145362.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# Heatmap to understand the correlation between all the numerical features. It shows Job Level and Monthly Income has
# #a strong correlation.Higher the performance rating,higher the salary hike.

# %% [markdown]
# # Distribution of Employee attrition

# %%
Attrition_count = data['Attrition'].value_counts()
Attrition_count

# %%
data['Attrition'].astype(str).value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# Distribution of attrition using bar graph

# %%
trace = go.Pie(labels = ['No_attrition', 'Yes_attrition'], values = data['Attrition'].value_counts(),
                        textfont = dict(size=15),opacity = 0.8,
                        marker = dict(colors = ['lightskyblue','gold'],
                         line = dict(color = '#000000', width = 1.5)))

layout = dict(title = 'Distribution of attrition variable')

fig = dict(data = [trace], layout = layout)
py.iplot(fig)

# %% [markdown]
# From above pie chart,we come to know that the % of No attrition is more than % of Yes attrition by 15%.

# %% [markdown]
# # Analysis of rating feature

# %%
#JobSatiesfaction
#Environment Satiesfaction
#RelationShip Satiesfaction
#jobinvolvement
#Worklifebalance
#performanceRating

# %%
data['JobSatisfaction'].value_counts()

# %% [markdown]
# 1=Low 2=Medium 3=High 4=Very High

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

labels = ['Low','Medium','High','Very High']

data['JobSatisfaction'].astype(str).value_counts().plot(kind='pie',figsize = (15,6),autopct='%1.1f%%',startangle=90,shadow=True,labels=None,ax=ax1)
ax1.set_title('Rating of Job Satisfaction by Employee')
fig.legend(labels = labels,loc = 'center')

data['EnvironmentSatisfaction'].astype(str).value_counts().plot(kind='pie',figsize = (15,6),autopct= '%1.1f%%',startangle =90,shadow = True,labels =None,ax = ax2)
ax2.set_title('Rating of EnvironmentSatisfaction by Employee')

data['RelationshipSatisfaction'].astype(str).value_counts().plot(kind ='pie',figsize= (15,6) ,autopct ='%1.1f%%',startangle= 90,shadow=True,labels=None,ax= ax3)
ax3.set_title('Rating of RelationshipSatisfaction by Employee')

data['JobInvolvement'].astype(str).value_counts().plot(kind='pie',figsize=(15,6),autopct='%1.1f%%',startangle=90,shadow=True,labels=None,ax=ax4)
ax4.set_title('Rating of JobInvolvement by Employee')

plt.show()

# %% [markdown]
# From the above chart we can say that
#
# (1) 49.5% of total count of employee are not satisfied with their job role.
#
# (2) 31.9% of employee are not having envirnment satisfaction.
#
# (3) 35.5% employees are not satisfied by their relationship with
#      other subordinates or office colleagues.
#
# (4) The maximum i.e 52.6% of employees are not sufficiently involved in their job
#     role which may also results in attrition.

# %%
fig2 = plt.figure()
ax5 = fig2.add_subplot(121)
ax6 = fig2.add_subplot(122)

labels_list1 = ['Bad','Good','Better','Best']
labels_list2 = ['Low','Good','Excellent','Outstanding']

data['WorkLifeBalance'].astype(str).value_counts().plot(kind = 'pie',figsize=(15,6),autopct='%1.1f%%',startangle=90,shadow=True,labels=None,ax=ax5)
ax5.set_title('Rating of Work-Life Balance by Employee')
ax5.legend(labels=labels_list1,loc = 'upper right')

data['PerformanceRating'].astype(str).value_counts().plot(kind = 'pie',figsize=(15,6),autopct='%1.1f%%',startangle=90,shadow=True,labels=None,ax=ax6)
ax6.set_title('Rating of Performance by Employee')
ax6.legend(labels = labels_list2,loc ='upper right')
plt.show()

# %% [markdown]
# 1. The above plot shows that 59.1% of the employee have rated their work life
# balanced as bad.
#
# 2. An almost of 67% of the employees earned low performance rating.

# %% [markdown]
# # Analysis of Work Experience

# %% [markdown]
# 1. Years at company
# 2. Years in current role
# 3. Years since last promotion
# 4. Years with current manager
# 5. Total working Years

# %%
we = data[['YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','TotalWorkingYears','Attrition']]
we.head()

# %%
YearsAtCompany = data.groupby('YearsAtCompany')['Attrition'].value_counts(normalize = False).unstack()
YearsAtCompany.plot(kind = 'bar',stacked = 'False',figsize = (10,6))
plt.title('Year At Company Employee')
plt.ylabel('Number of Employee')
plt.show()

# %% [markdown]
# From the above chart we observed that the employees with less of years of
# experience or have invested less years with same company are having highest rate
# of quitting the job.Thus, more concern should be given to the freshers or experience
# lacker and the causes behind quitting the job by newly arrived professionals should
# be investigated.

# %%
YearsInCurrRole = data.groupby('YearsInCurrentRole')['Attrition'].value_counts(normalize = False).unstack()
YSLP = data.groupby('YearsSinceLastPromotion')['Attrition'].value_counts(normalize=False).unstack()

fig = plt.figure()
ax0 = fig.add_subplot(121)
ax1 = fig.add_subplot(122)

YearsInCurrRole.plot(kind = 'bar',stacked = 'False',figsize = (20,8),ax=ax0)
ax0.set_title("Same Role")
ax0.set_xlabel('Years In Current Role')
ax0.set_ylabel('Number of Employees')

YSLP.plot(kind = 'bar',stacked = 'False',figsize = (20,8),ax=ax1)
ax1.set_title("Last Promotion")
ax1.set_xlabel('Years Since Last Promotion')
ax1.set_ylabel("Number of Employees")
plt.show()

# %% [markdown]
# 1. From the above chart which is showing the comparison of attrition of employees
#    having varied number of years at the company, we come to know that the
#    attrition rate is at the highest level in period on 0-1 year and at the same
#    time by observation we come to know that in comparison of the period 0-2
#    years and 2-3 years,we have seen a sudden drop in rate of employee
#    attrition.
# 2. The comparative chart of 'Number of Employees' and 'Years Since last
#    promotion' tells us that the employees do not tend to continue on the same post
#    with the increasing number of years.

# %%
YWCM=data.groupby("YearsWithCurrManager")["Attrition"].value_counts(normalize=False).unstack()
YWCM.plot(kind='bar',stacked='False',figsize=(20,8))
plt.title("Years With Current Manager")

plt.ylabel("Number of  Employees")
plt.show()

# %% [markdown]
# The above graph gives us the comparison between 'number of employees who
# worked with current manager' and 'the respective years they have invested with
# current manager', thus we get the result as the starting phase of the career or at the
# start of new job role at new company, attrition rate is high within the span of 2 years.
# As well as, this analysis is very much subjective but still it is noticed that the work
# relation with manager and the employee is not that good hence it is recommended
# that manager should try to communicate with the employee in order to decrease the
# attrition rate.

# %%
TWE=data.groupby("TotalWorkingYears")["Attrition"].value_counts(normalize=False).unstack()
TWE.plot(kind="bar",stacked='False',figsize=(10,8))
plt.title("Total Working Years")

plt.ylabel("Number of  Employees")
plt.show()

# %% [markdown]
# It is observed that there is high number of employee who leaves company at (0-5) years of experience. So it is very important that company to create such a policy to handle freshers so that they don't leave the company at the start of thier career.

# %% [markdown]
# visualize some continous data
# age vs Attrition

# %%
sns.jointplot(x='Attrition', y='TotalWorkingYears',data=data)

# %% [markdown]
# # Analysis of Monthly Income

# %%
mi = data[data['Attrition'] == 'Yes']['MonthlyIncome']
mi = mi.reset_index()
mi.drop(['index'],axis = 1,inplace = True)

mn = data[data['Attrition'] == 'No']['MonthlyIncome']
mn = mn.reset_index()
mn.drop(['index'],axis = 1,inplace = True)

mi['mn'] = mn
mi.rename(columns = {'MonthlyIncome':'Yes','mn':'No'},inplace = True)
mi.head()

# %%
data.groupby('Attrition')['MonthlyIncome'].mean()

# %%
mi.plot(kind='box',figsize = (10,7))
plt.title('Box plot Monthly Income vs Attrition')
plt.ylabel('Monthly Income')
plt.show()

# %% [markdown]
# We can say if employee get average salary employee do  ot leave company.

# %% [markdown]
# # Is Attrition depends on percentage salary hike?

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'PercentSalaryHike',hue = 'Attrition',data = data)
plt.show()

# %% [markdown]
# By observing above chart we come to the conclusion that while giving salary hike,
# attrition is at the highest at the 11% as well as we can also say that discussing salary
# hike ranging from 11% to 13% tends to give attrition rate from maximum to minimum.
# We can also say that company should try to give average hike by 13% so that
# attrition will be minimal.

# %% [markdown]
# # Over Time employee Analysis

# %%
dot = data[['OverTime','MonthlyIncome','Attrition']]
oyay = dot[(data['OverTime'] == 'Yes') & (data['Attrition'] == 'Yes')]
oyay = oyay.sort_values(by = 'MonthlyIncome',ascending =False,axis = 0)
count,bin_edges = np.histogram(oyay['MonthlyIncome'])
oyay.plot(kind = 'hist',xticks = bin_edges,figsize = (10,10))
plt.show()

# %%
r = data.groupby('OverTime')['OverTime'].count()
plt.pie(r, explode = [0.05,0.1], labels = ['No','Yes'],radius=1.5, autopct='%1.1f%%',shadow = True)
plt.show()

# %% [markdown]
# The above chart tells us that overall 50.4% of total employees don't work for
# overtime.

# %% [markdown]
# # How is attrition affected by gender?

# %%
plt.figure(figsize=(8,5))
total = float(len(data))
plt.subplot(1,2,1)
ay=sns.countplot(x="Gender",data=data)
for p in ay.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ay.annotate(percentage, (x, y),ha='right')
plt.subplot(1,2,2)
ax = sns.countplot(x="Gender", hue="Attrition", data=data)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.show()

# %% [markdown]
# The rate of male employee is more i.e 1% as compare to attrition of
# female employee.

# %% [markdown]
# # What is effect of age on attrition?

# %%
#Histogram showing the age distribution of the employees

plt.hist(data['Age'])
plt.xlabel('Age of employees')
plt.ylabel('Count')
plt.title('Age count of Employees')
plt.show()

# %% [markdown]
# From above graph knows that the count of employee is higher over 58 age.

# %%
plt.figure(figsize = (15,5))
sns.countplot(x = 'Age' ,hue = 'Attrition' ,data = data)
plt.show()

# %% [markdown]
# From the above chart which is showing the attrition rate according to age distribution
# here we come to know that at the age of 27 to 41 there is employee attrition rate is
# highest, on the other side experience peoples attrition rate is low.

# %% [markdown]
# # What is Age density distribution by attrition?

# %%
attrition_yes = data.loc[data["Attrition"] == 'Yes']
attrition_no = data.loc[data["Attrition"] == 'No']

# %%
plt.figure(figsize=(6,4))
ax = sns.distplot(attrition_yes["Age"],hist=False,label="Yes",color="r")
ax = sns.distplot(attrition_no["Age"],hist=False,label="No",color="#C0EDD2")

plt.ylabel("Density")
plt.legend()
# Get the two lines from the axes to generate shading
l1 = ax.lines[0]
l2 = ax.lines[1]

# Get the xy data from the lines so that we can shade
x1 = l1.get_xydata()[:,0]
y1 = l1.get_xydata()[:,1]
x2 = l2.get_xydata()[:,0]
y2 = l2.get_xydata()[:,1]
ax.fill_between(x1,y1, color="red", alpha=0.3)
ax.fill_between(x2,y2, color="#C0EDD2", alpha=0.3)
sns.despine()
ax.text(5,0.064,"Age Density Distribution by Attrition",
        fontsize=15,        
         fontweight='bold') 
ax.text(5,0.06,"The older you get, the less you want to change jobs?",
        fontsize=12) 
plt.show(block=False)

# %% [markdown]
# The above displot shows that the attrition rate in the age group of 20 to 40
# and the attrition rate decreased for the age above 45.

# %% [markdown]
# # How is Attrition Affected by business travels?

# %%
sns.countplot(x = 'BusinessTravel', hue = 'Attrition', data = data)
plt.show()

# %%
data.groupby('BusinessTravel')['Attrition'].value_counts()

# %% [markdown]
# Most employees who travel rarely don't leave the company.From the above plot we
# come to know that sending employees on business travels are not doesn't really
# make much of a difference and doesn't have a significant effect on attrition.
#
# So the Business Travel is not one of the main factor causing attrition but who travel
# frequently have biggest percentage.
#
# Best way to reduce this attrition is to conduct monthly survey and to assign travel
# according to the employee business travel interest.

# %% [markdown]
# # What is the most Department of attritions?

# %%
data['Department'].value_counts()

# %%
dpm = data.groupby('Department')['Attrition'].value_counts().unstack()
dpm = dpm.transpose()
dpm

# %%
plt.figure(figsize = (15,6))
sns.countplot(x = 'Department', hue = 'Attrition' ,data = data)
plt.show()

# %% [markdown]
# By observing above chart we come to know that attritions are from the
# research & development. Support has the least number of attrition.But
# we need to keep in mind that R&D has a lot more employees than other department.
#
# If we considered percentage of attrition per department, we would see that the R&D
# department has most attrition.

# %% [markdown]
# # What is effect of the distance from home on attrition?

# %%
data.groupby('DistanceFromHome')['Attrition'].value_counts().unstack()

# %%
plt.figure(figsize=(20,10))
total = float(len(data))
for p in ay.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ay.annotate(percentage, (x, y),ha='right')

ax = sns.countplot(x="DistanceFromHome", hue="Attrition", data=data)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.show()

# %% [markdown]
# By observing above chart we come to know that Most of the people who leave the company are
# located more than 28km away from the company.This might be reason of employee attrition.

# %% [markdown]
# # What is effect of the DailyRate on attrition?

# %%
sns.distplot(data['DailyRate'], kde = False, color = 'green')
plt.show()

# %%
data['DailyRate'].value_counts()

# %% [markdown]
# # Analysis of maritual Status

# %%
data['MaritalStatus'] = data['MaritalStatus'].replace('Singlle','Single')

# %%
ms = data[['MaritalStatus' , 'Attrition']]
ms.head()

# %%
ms['MaritalStatus'].value_counts()

# %%
ms['MaritalStatus'].value_counts().plot(kind="pie",figsize=(15,6),autopct='%1.1f%%',startangle=90,labels=None)
plt.axis('equal')
plt.legend(labels=['Married','Single','Divorced'],loc='upper left')
plt.show()

# %% [markdown]
# The above chart tells us that overall 66.0% of total employees are married in company.

# %%
Ms = data.groupby('MaritalStatus')['Attrition'].value_counts().unstack()
Ms = Ms.transpose()
Ms

# %%
plt.figure(figsize = (10,6))
sns.countplot(x = 'MaritalStatus',hue = 'Attrition' ,data =data)
plt.show()

# %% [markdown]
# from the above graph we can say that the count of married employees to leave the company is high.
# But it is also important that the company  has a large number of married employees.

# %% [markdown]
# # Do Education Field play a role?

# %%
data['Education'].value_counts().plot(kind="pie",figsize=(15,6),autopct='%1.1f%%',startangle=90,labels=None)
plt.axis('equal')
plt.show()

# %%
Ed = data.groupby('Education')['Attrition'].value_counts().unstack()
Ed = Ed.transpose()
Ed

# %%
plt.figure(figsize = (15, 5))
plt.xticks(rotation=90)
sns.countplot(x = 'Education',hue='Attrition', data = data)
plt.show()

# %% [markdown]
# From the above chart we know that for level 1 and 2 of education have more attrition rate.

# %% [markdown]
# # Analysis of Job Role

# %%
JR = data.groupby('JobRole')['Attrition'].value_counts().unstack()
JR = JR.transpose()
JR

# %%
data['JobRole'].value_counts().plot(kind="pie",figsize=(15,10),autopct='%1.1f%%',startangle=90,labels=None)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize = (20, 5))
plt.xticks(rotation=90)
sns.countplot(x = 'JobRole',hue='Attrition', data = data )
plt.show()

# %% [markdown]
# From the above graph we can say that most of the developers and sales executive
# leave the organization.therefore, there is a need to give promotion and incentives according  to
# work. The manager should try to communicate with the employees to reduce the
# attrition rate.
